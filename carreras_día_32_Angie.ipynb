# %% [markdown]
# # 🎃🧛🧙‍♀️👹🧟👻

# %%
📣 ¡¡Boo !! 👻🤡

# %% [markdown]
# ![1.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# ##Parte 1 🦉
#
# Crear un porgrama al que se le indique si se desea realizar "truco o trato" y un listado de persona (array) con:
#
# Nombre
#
# *Edad
#
# *Altura en centímetros

# %% [markdown]
# **#PARTE 1 🦄**
# ⚗

# %%
import random
import math
emojis="🍡🍡🧁🧁🍭🍭🍫🍫🍬🍬"

class Persona():
  def __init__(self,nombre,edad,altura,):
    self.nombre=nombre
    self.edad=edad
    self.altura=altura
 
  def opcion(self,accion):
    if accion=="truco":
      print("Troliado por chistoso UwU")
      print(primera.__dict__)
    elif accion=="trato":
      contar=0
      for i in self.nombre:
        contar+=1
      if self.edad>=10:
        contar+=3
      else:
        contar+=math.floor(self.edad/3)
      if self.altura>=150:
        contar+=6
      else:
            contar+=2*math.floor(self.altura/50)

      print(f'{contar} dulces')
      print("".join(random.choice(emojis) for i in range(contar)))
      print(primera.__dict__)

# %% [markdown]
# ![RUTA B.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# ##Parte 2 B 🦇
#
# Si las personas han pedido trato, el programa retornara dulces (aleatorios) siguiendo los siguientes criterios:
#
# *Un dulce por cada letra de nombre
#
# *Un dulce por cada 3 años cumplidos hasta un máximo de 10 años por persona
#
# *Dos dulces por cada 50cm de altura hasta un máximo de 150cm por persona

# %% [markdown]
# #PARTE B

# %%
while True:
  print("}-----------------------------------{")
  nombre2=str(input("Ingrese el nombre: "))
  nombre2=nombre2.capitalize()
  edad2=int(input("Ingrese la edad: "))
  alturita=int(input("Ingrese la altura en centímetros: "))
  primera=Persona(nombre2,edad2,alturita)
  print("¿Qué quiere hacer? [Truco o trato]")
  a=str(input("Ingrese la acción que desea realizar: "))
  a=a.lower()
  while a!="truco" and a!="trato":
    a=str(input("Ingrese una acción válida: "))
    a=a.lower()
  primera.opcion(a)
  print("}-----------------------------------{")
  print("¿Hay más personas pidiendo dulces?")
  eleccion=str(input("Si->si / No->no: "))
  while eleccion!="si" and eleccion!="no":
    print("Ingrese una opción válida")
    eleccion=str(input("Si->si / No->no: "))
  if eleccion=="no":
    print(", 🧛👻🎃👻Feliz Halloween👻🎃👻, 🧛")
    break
# Out:
# }-----------------------------------{
# Ingrese el nombre: Leo
# Ingrese la edad: 20
# Ingrese la altura en centímetros: 170
# ¿Qué quiere hacer? [Truco o trato]
# Ingrese la acción que desea realizar: truco
# Troliado por chistoso UwU
# {'nombre': 'Leo', 'edad': 20, 'altura': 170}
# }-----------------------------------{
# ¿Hay más personas pidiendo dulces?
# Si->si / No->no: si
# }-----------------------------------{
# Ingrese el nombre: Ana
# Ingrese la edad: 18
# Ingrese la altura en centímetros: 150
# ¿Qué quiere hacer? [Truco o trato]
# Ingrese la acción que desea realizar: trato
# 12 dulces
# 🍭🧁🍭🍫🍬🧁🍫🍭🍫🧁🍭🍭
# {'nombre': 'Ana', 'edad': 18, 'altura': 150}
# }-----------------------------------{
# ¿Hay más personas pidiendo dulces?
# Si->si / No->no: si
# }-----------------------------------{
# Ingrese el nombre: Ximena
# Ingrese la edad: 19
# Ingrese la altura en centímetros: 165
# ¿Qué quiere hacer? [Truco o trato]
# Ingrese la acción que desea realizar: truco
# Troliado por chistoso UwU
# {'nombre': 'Ximena', 'edad': 19, 'altura': 165}
# }-----------------------------------{
# ¿Hay más personas pidiendo dulces?
# Si->si / No->no: no
# , 🧛👻🎃👻Feliz Halloween👻🎃👻, 🧛
